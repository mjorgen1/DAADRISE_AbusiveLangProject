# %%
import numpy as np
import seaborn
import pandas as pd
import matplotlib.pyplot as plt

matrix_proportions = np.zeros((3,3))
# For Eng Recall Matrix 1000Uni+CNN
#matrix = np.array([[0.62, 0.27, 0.1], [0.07, 0.9, 0.04], [0.03, 0.03, 0.93]])

# For Eng Recall Matrix 1000Uni+RandomUndersampling
matrix = np.array([[0.77, 0.15, 0.08], [0.17, 0.8, 0.03], [0.08, 0.02, 0.9]])

for i in range(0,3):
    matrix_proportions[i,:] = matrix[i,:]
names=['Hateful','Offensive','Neither']
confusion_df = pd.DataFrame(matrix_proportions, index=names,columns=names)
plt.figure(figsize=(5,5))
seaborn.heatmap(confusion_df,annot=True,annot_kws={"size": 12},cmap='gist_gray_r',cbar=False, square=True,fmt='.2f')
plt.ylabel(r'True categories',fontsize=14)
plt.xlabel(r'Predicted categories',fontsize=14)
plt.tick_params(labelsize=12)
plt.savefig('Eng1000UniRandUnderSamprecall.jpg', dpi=600)
plt.show()

# %%
import numpy as np
import seaborn
import pandas as pd
import matplotlib.pyplot as plt

matrix_proportions = np.zeros((3,3))
# German Recall Matrix 30 mins
matrix = np.array([[0.74, 0.11, 0.15], [0.29, 0.54, 0.17], [0.24, 0.11, 0.65]])

#German Recall Matrix 2 hrs
matrix = np.array([[0.69, 0.15, 0.17], [0.22, 0.61, 0.17], [0.24, 0.12, 0.64]])

for i in range(0,3):
    matrix_proportions[i,:] = matrix[i,:]
names=['Other','Insult','Abuse']
confusion_df = pd.DataFrame(matrix_proportions, index=names,columns=names)
plt.figure(figsize=(5,5))
seaborn.heatmap(confusion_df,annot=True,annot_kws={"size": 12},cmap='gist_gray_r',cbar=False, square=True,fmt='.2f')
plt.ylabel(r'True categories',fontsize=14)
plt.xlabel(r'Predicted categories',fontsize=14)
plt.tick_params(labelsize=12)
plt.savefig('Germ2hrsrecall.jpg', dpi=600)
plt.show()
